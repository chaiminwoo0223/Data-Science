# %% [markdown]
# <a href="https://colab.research.google.com/github/chaiminwoo0223/Data-Science/blob/main/01%20-%20Visualization.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Import

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # 수치형 데이터 시각화
# ## 1.히스토그램
# - 수치형 데이터의 구간별 빈도수를 나타내는 그래프

# %%
titanic = sns.load_dataset('titanic')
titanic.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
sns.histplot(data = titanic, x = 'age')
# Out:
# <Axes: xlabel='age', ylabel='Count'>

# %%
# bins : 구간의 개수를 지정
sns.histplot(data = titanic, x = 'age', bins = 10)
# Out:
# <Axes: xlabel='age', ylabel='Count'>

# %%
# hue : 범주별로 표현
# 회색 : 사망자수와 생존자수가 겹친 부분
sns.histplot(data = titanic, x = 'age', hue = 'alive')
# Out:
# <Axes: xlabel='age', ylabel='Count'>

# %%
# multiple = 'stack' : 범주별로 누적해서 표현
sns.histplot(data = titanic, x = 'age', hue = 'alive', multiple = 'stack')
# Out:
# <Axes: xlabel='age', ylabel='Count'>

# %% [markdown]
# ## 2.커널밀도추정함수 그래프
# - 히스토그램을 매끄럽게 곡선으로 연결한 그래프

# %%
sns.kdeplot(data = titanic, x = 'age', hue = 'alive', multiple = 'stack')
# Out:
# <Axes: xlabel='age', ylabel='Density'>

# %% [markdown]
# ## 3.분포도
# - 수치형 데이터 하나의 분포를 나타내는 그래프
# - 파라미터만 조정하면, histplot()과 kdeplot()이 제공하는 기본 그래프를 모두 그릴 수 있다.

# %%
# 히스토그램
sns.displot(data = titanic, x = 'age')

# %%
# kind = 'kde' : 커널밀도추정함수
sns.displot(data = titanic, x = 'age', kind = 'kde')

# %%
# kde = True : 히스토그램과 커널밀도함수를 동시에 그린다.
sns.displot(data = titanic, x = 'age', kde = True)

# %% [markdown]
# ## 4.러그플롯
# - 주변분포(marginal distribution)을 나타내는 그래프
# - 단독으로 사용하기 보다는, 주로 다른 분포도 그래프와 함께 사용한다.

# %%
sns.kdeplot(data = titanic, x = 'age')
sns.rugplot(data = titanic, x = 'age')
# Out:
# <Axes: xlabel='age', ylabel='Density'>

# %% [markdown]
# # 범주형 데이터 시각화
# ## 1.막대그래프
# - 범주형 데이터 값에 따라, 수치형 데이터 값이 어떻게 달라지는지 파악할 때 사용한다.
# - 평균 : 막대 높이, 신뢰구간 : 오차 막대

# %%
# 신뢰구간이 넓다. = 표준편차가 크다.
sns.barplot(x = 'class', y = 'fare', data = titanic)
# Out:
# <Axes: xlabel='class', ylabel='fare'>

# %% [markdown]
# ## 2.포인트플롯
# - 범주형 데이터 값에 따라, 수치형 데이터 값이 어떻게 달라지는지 파악할 때 사용한다.
# - 점과 선

# %%
sns.pointplot(x = 'class', y = 'fare', data = titanic)
# Out:
# <Axes: xlabel='class', ylabel='fare'>

# %% [markdown]
# ## 3.박스플롯
# - 5가지 요약 수치 : 최솟값, 제1사분위 수(Q1), 제2사분위 수(Q2), 제3사분위 수(Q3), 최댓값
# - 사분위 범위 수(IQR) : Q3 - Q1
# - 이상치 : 최솟값보다 작은 값과 최댓값의 큰 값

# %%
sns.boxplot(x = 'class', y = 'age', data = titanic)
# Out:
# <Axes: xlabel='class', ylabel='age'>

# %% [markdown]
# ## 4.바이올린플롯
# - 박스플롯 + 커널밀도추정함수

# %%
sns.violinplot(x = 'class', y = 'age', data = titanic)
# Out:
# <Axes: xlabel='class', ylabel='age'>

# %%
# '성별'에 따른 '등급'별 '나이' 분포
sns.violinplot(x = 'class', y = 'age', data = titanic, split = True, hue = 'sex')
# Out:
# <Axes: xlabel='class', ylabel='age'>

# %% [markdown]
# ## 5.카운트플롯
# - 범주형 데이터의 개수를 확인할 때 사용하는 그래프

# %%
# X축
sns.countplot(x = 'class', data = titanic)
# Out:
# <Axes: xlabel='class', ylabel='count'>

# %%
# Y축
sns.countplot(y = 'class', data = titanic)
# Out:
# <Axes: xlabel='count', ylabel='class'>

# %% [markdown]
# ## 6.파이그래프
# - 범주형 데이터별 비율을 알아볼 때 사용하기 좋은 그래프

# %%
x = [10, 60, 30]         # 비율
labels = ['A', 'B', 'C'] # 레이블

plt.pie(x = x, labels = labels, autopct = '%.1f%%')
# Out:
# ([<matplotlib.patches.Wedge at 0x7d18ed3ba8f0>,
# ...
#  [Text(1.0461621663333946, 0.3399186987098808, 'A'),
#   Text(-0.8899187482945419, 0.6465637025335369, 'B'),
#   Text(0.6465639524941308, -0.8899185666875186, 'C')],
#  [Text(0.5706339089091244, 0.1854101992962986, '10.0%'),
#   Text(-0.4854102263424773, 0.3526711104728383, '60.0%'),
#   Text(0.35267124681498035, -0.485410127284101, '30.0%')])

# %% [markdown]
# # 데이터 관계 시각화
# ## 1.히트맵
# - 데이터 간 관계를 색상으로 표현한 그래프
# - 비교해야 될 데이터가 많을 때 주로 사용한다.

# %%
flights = sns.load_dataset('flights')
flights.head()
# Out:
#    year month  passengers
# 0  1949   Jan         112
# 1  1949   Feb         118
# 2  1949   Mar         132
# 3  1949   Apr         129
# 4  1949   May         121

# %%
flights_pivot = flights.pivot(index = 'month', columns = 'year', values = 'passengers')
flights_pivot
# Out:
# year   1949  1950  1951  1952  1953  1954  1955  1956  1957  1958  1959  1960
# month
# Jan     112   115   145   171   196   204   242   284   315   340   360   417
# Feb     118   126   150   180   196   188   233   277   301   318   342   391
# Mar     132   141   178   193   236   235   267   317   356   362   406   419
# Apr     129   135   163   181   235   227   269   313   348   348   396   461
# May     121   125   172   183   229   234   270   318   355   363   420   472
# Jun     135   149   178   218   243   264   315   374   422   435   472   535
# Jul     148   170   199   230   264   302   364   413   465   491   548   622
# Aug     148   170   199   242   272   293   347   405   467   505   559   606
# Sep     136   158   184   209   237   259   312   355   404   404   463   508
# Oct     119   133   162   191   211   229   274   306   347   359   407   461
# Nov     104   114   146   172   180   203   237   271   305   310   362   390
# ...

# %%
sns.heatmap(data = flights_pivot)
# Out:
# <Axes: xlabel='year', ylabel='month'>

# %% [markdown]
# ## 2.라인플롯
# - 두 수치형 데이터 사이의 관계를 나타날 때 사용한다.
# - X 파라미터에 전달한 값에 따라, Y 파라미터에 전달한 값의 평균과 95% 신뢰구간을 나타낸다.

# %%
sns.lineplot(x = 'year', y = 'passengers', data = flights)
# Out:
# <Axes: xlabel='year', ylabel='passengers'>

# %% [markdown]
# ## 3.산점도
# - 두 데이터의 관계를 점으로 표현하는 그래프

# %%
tips = sns.load_dataset('tips')
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
sns.scatterplot(x = 'total_bill', y = 'tip', data = tips)
# Out:
# <Axes: xlabel='total_bill', ylabel='tip'>

# %%
sns.scatterplot(x = 'total_bill', y = 'tip', data = tips, hue = 'time')
# Out:
# <Axes: xlabel='total_bill', ylabel='tip'>

# %% [markdown]
# ## 4.회귀선을 포함한 산점도 그래프
# - 산점도 + 선형 회귀선

# %%
# 신뢰구간 = 95%
sns.regplot(x = 'total_bill', y = 'tip', data = tips)
# Out:
# <Axes: xlabel='total_bill', ylabel='tip'>

# %%
# 신뢰구간 = 99%
sns.regplot(x = 'total_bill', y = 'tip', data = tips, ci = 99)
# Out:
# <Axes: xlabel='total_bill', ylabel='tip'>
